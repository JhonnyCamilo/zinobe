# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
pd.__version__
import numpy as np
# %time df_America = pd.read_json('https://restcountries.eu/rest/v2/region/Americas')
d=df_America.loc[3,['languages']]
d0=df_America.loc[3,['name']]
d1 = pd.DataFrame(d)
d00=np.array([d0])[0][0]
d000=d00
e=np.array([d1])[0][0][0]
e1 = pd.DataFrame(e)
r1=e1.loc[0,['nativeName']]
r2=r1['nativeName']
import hashlib 
str = hashlib.sha1(r2.encode()) 
str
str_hex = str.hexdigest()
# %time df_Africa = pd.read_json('https://restcountries.eu/rest/v2/region/Africa')
dA=df_Africa.loc[12,['languages']]
d0A=df_Africa.loc[12,['name']]
d1A = pd.DataFrame(dA)
d00A=np.array([d0A])[0][0]
d000A=d00A
eA=np.array([d1A])[0][0][0]
e1A = pd.DataFrame(eA)
r1A=e1A.loc[0,['nativeName']]
r2A=r1A['nativeName']
import hashlib 
strA = hashlib.sha1(r2A.encode()) 
strA
str_hexA = strA.hexdigest()
# %time df_Oceania = pd.read_json('https://restcountries.eu/rest/v2/region/Oceania')
dO=df_Oceania.loc[15,['languages']]
d0O=df_Oceania.loc[15,['name']]
d1O = pd.DataFrame(dO)
d00O=np.array([d0O])[0][0]
d000O=d00O
eO=np.array([d1O])[0][0][0]
e1O = pd.DataFrame(eO)
r1O=e1O.loc[0,['nativeName']]
r2O=r1O['nativeName']
import hashlib 
strO = hashlib.sha1(r2O.encode()) 
strO
str_hexO = strO.hexdigest()

# %time df_Europe = pd.read_json('https://restcountries.eu/rest/v2/region/Europe')
dE=df_Europe.loc[25,['languages']]
d0E=df_Europe.loc[25,['name']]
d1E = pd.DataFrame(dE)
d00E=np.array([d0E])[0][0]
d000E=d00E
eE=np.array([d1E])[0][0][0]
e1E = pd.DataFrame(eE)
r1E=e1E.loc[0,['nativeName']]
r2E=r1E['nativeName']
import hashlib 
strE = hashlib.sha1(r2E.encode()) 
strE
str_hexE = strE.hexdigest()
 
# %time df_Asia = pd.read_json('https://restcountries.eu/rest/v2/region/Asia')
dC=df_Asia.loc[2,['languages']]
d0C=df_Asia.loc[2,['name']]
d1C = pd.DataFrame(dC)
d00C=np.array([d0C])[0][0]
d000C=d00C
eC=np.array([d1C])[0][0][0]
e1C = pd.DataFrame(eC)
r1C=e1C.loc[0,['nativeName']]
r2C=r1C['nativeName']
import hashlib 
strC = hashlib.sha1(r2C.encode()) 
strC
# %time str_hexC = strC.hexdigest()
tabla_final = {'Pais' : [d000, d000A, d000O, d000E, d000C], 'Lenguaje' :[str_hex, str_hexA, str_hexO, str_hexE, str_hexC] }
d34 = pd.DataFrame(tabla_final)
d34
# Out:
# CPU times: user 21.3 ms, sys: 937 µs, total: 22.2 ms
# Wall time: 229 ms
# CPU times: user 19.9 ms, sys: 977 µs, total: 20.9 ms
# Wall time: 167 ms
# CPU times: user 17.7 ms, sys: 2.14 ms, total: 19.8 ms
# Wall time: 144 ms
# CPU times: user 18.9 ms, sys: 51 µs, total: 19 ms
# Wall time: 151 ms
# CPU times: user 18.9 ms, sys: 906 µs, total: 19.8 ms
# Wall time: 151 ms
# CPU times: user 9 µs, sys: 1e+03 ns, total: 10 µs
# Wall time: 12.4 µs
#              Pais                                  Lenguaje
# 0           Aruba  f61c54c1d70775fd5bb25406d1186806fe1569a0
# 1           Congo  68437bf96454e8b454d9e60af59d98f9e603b994
# 2  Norfolk Island  649df08a448ee3fa90f3746baaf6b0907df42c91
# 3           Italy  21df73947a06d77d2ad5fe166c8ddfcdc53a6fdb
# 4      Azerbaijan  d7ada18413fe231f17fc1c852c3e335345cf05d8

# %%
dir_pandas = ('/content/drive/My Drive/pandas/{}')
dir_pandas
# Out:
# '/content/drive/My Drive/pandas/{}'

# %%
d34.to_json(dir_pandas.format('dataframe.json'))
